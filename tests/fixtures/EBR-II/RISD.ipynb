# %% [markdown]
# # install dependencies

# %%
# !pip3 install inverse-canopy==0.0.21
# Out:
# Collecting inverse-canopy==0.0.21
#   Downloading inverse_canopy-0.0.21-py3-none-any.whl (28 kB)
# Requirement already satisfied: tensorflow>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from inverse-canopy==0.0.21) (2.15.0)
# Requirement already satisfied: tensorflow-probability>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from inverse-canopy==0.0.21) (0.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from inverse-canopy==0.0.21) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from inverse-canopy==0.0.21) (1.11.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from inverse-canopy==0.0.21) (3.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.23.0->inverse-canopy==0.0.21) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.23.0->inverse-canopy==0.0.21) (2.2.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from tensorflow-probability>=0.23.0->inverse-canopy==0.0.21) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->inverse-canopy==0.0.21) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.15.0->inverse-canopy==0.0.21) (3.2.2)
# Installing collected packages: inverse-canopy
# Successfully installed inverse-canopy-0.0.21

# %% [markdown]
# # **Model Inputs**

# %%
from inverse_canopy import InverseCanopy
import tensorflow as tf
import numpy as np

# %%
tunable = {
 'num_samples': 1000,      # number of monte carlo samples
 'learning_rate': 0.1,    # the gradient update rate
 'dtype': tf.float64,     # use 64-bit floats
 'epsilon': 1e-20,        # useful for avoiding log(0 + epsilon) type errors
 'max_steps': 5000,       # maximum steps, regardless of convergence
 'patience': 50,          # number of steps to wait before early stopping if the loss does not improve
 'initiating_event_frequency': 1e-5,  # set the initiating event (IE) frequency here
 'freeze_initiating_event': True,       # set to False if you'd like to predict the IE frequency as well
}

conditional_events = {
    'names': ['RISD', 'RSIG', 'RROD', 'PRUN', 'BPHR', 'DHRS', 'DHRL'],
    'bounds': {
        'mean': {
            'min': 1e-14,
            'max': 1.00,
        },
        'std': {
            'min': 1e-10,
            'max': 1e8,
        },
     },
    'initial': {
       'mean': 5e-1,
       'std': 1e8,
    }
}

end_states = {
    # 'RISD-0': {
    #     'sequence': [0, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan],
    #     'probability': 1 - 7.7e-3 - 6.5e-11 - 4.41e-11 - 1e-11 - 1e-11 - 3.49e-8 - 7.0e-11 - 2.5e-8
    # },
    'RISD-1': {
        'sequence': [1, 0, 0, np.nan, 0, np.nan, 0],
        'probability': 1e-5,
    },
    'RISD-2': {
        'sequence': [1, 0, 0, np.nan, 0, np.nan, 1],
        'probability': 1e-11,
    },
    'RISD-3': {
        'sequence': [1, 0, 0, np.nan, 1, 0, 0],
        'probability': 1e-6,
    },
    'RISD-4': {
        'sequence': [1, 0, 0, np.nan, 1, 0, 1],
        'probability': 1e-11,
    },
    'RISD-5': {
        'sequence': [1, 0, 0, np.nan, 1, 1, np.nan],
        'probability': 1e-11,
    },
    'RISD-6': {
        'sequence': [1, 0, 1, 0, np.nan, np.nan, np.nan],
        'probability': 1e-11,
    },
    'RISD-7': {
        'sequence': [1, 0, 1, 1, np.nan, np.nan, np.nan],
        'probability': 1e-11,
    },
    'RISD-8': {
        'sequence': [1, 1,np.nan, np.nan, np.nan, np.nan, np.nan],
        'probability': 1e-11,

    },


}

model = InverseCanopy(conditional_events, end_states, tunable)
model.fit(steps=tunable['max_steps'], patience=tunable['patience'], learning_rate=tunable['learning_rate'])
model.summarize(show_metrics=False)
# Out:
# tunable initialized: dtype=<dtype: 'float64'>, epsilon=1e-20
# learning_rate: 0.1,patience: 50,min_improvement: 0.001,max_steps: 5000,seed: 372
# Step 0: Loss = 10.3552494478909871, performing 43.9 it/sec
# Step 100: Loss = 2.0549203695883556, performing 104.7 it/sec
# Step 200: Loss = 0.2556694325704684, performing 66.5 it/sec
# No improvement since Step 226, early stopping.
# [Best]  Step 225: Loss = 0.1463459621678737
# [Final] Step 275: Loss = 0.1500876293966122
#
# predicted end states
# ------------------------------------
#          5th       Mean      95th
# RISD-1  8.52e-06  8.52e-06  8.52e-06
# RISD-2  2.31e-11  2.31e-11  2.31e-11
# RISD-3  1.48e-06  1.48e-06  1.48e-06
# RISD-4  3.99e-12  3.99e-12  3.99e-12
# RISD-5  9.74e-12  9.74e-12  9.74e-12
# RISD-6  9.72e-12  9.72e-12  9.72e-12
# RISD-7  1.01e-11  1.01e-11  1.01e-11
# RISD-8  9.96e-12  9.96e-12  9.96e-12
#
#
# predicted conditional events
# ----------------------------------
#        5th       Mean      95th
# RISD  1.00e+00  1.00e+00  1.00e+00
# RSIG  9.96e-07  9.96e-07  9.96e-07
# RROD  1.98e-06  1.98e-06  1.98e-06
# PRUN  5.09e-01  5.09e-01  5.09e-01
# BPHR  1.48e-01  1.48e-01  1.48e-01
# DHRS  6.60e-06  6.60e-06  6.60e-06
# DHRL  2.71e-06  2.71e-06  2.71e-06
